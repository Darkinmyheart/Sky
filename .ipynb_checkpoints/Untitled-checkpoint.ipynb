# %%
print("*******************************")
print("")
print("* Name: Lê Quang Thiên *")
print("* Center: CodeGym *")
print("* Course: Python Fundamental *")
print("")
print("*******************************")
# Out:
# *******************************
#
# * Name: Lê Quang Thiên *
# * Center: CodeGym
# * Course: Python Fundamental
#
# *******************************
